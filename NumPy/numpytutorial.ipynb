# %% [markdown]
# # welcome to numpy tutorial

# %%
import numpy as np

# %%
myarr=np.array([[3,4,5,66]],np.int32)

# %%
myarr[0,1]
# Out:
# np.int32(4)

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int32')

# %%
myarr[0,1]=34

# %%
myarr
# Out:
# array([[ 3, 34,  5, 66]], dtype=int32)
